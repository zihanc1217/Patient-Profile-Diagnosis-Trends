# %% [markdown]
# # Patient Profile & Diagnosis Trends

# %% [markdown]
# 1. Load data

# %%
import pandas as pd 
import numpy as np 

df = pd.read_csv('patient_visits.csv')

df['visit_date'] = pd.to_datetime(df['visit_date'])
df['date_of_birth'] = pd.to_datetime(df['date_of_birth'])

print(df.head(5))

print(df.info())
# Out:
#   visit_id patient_id visit_date date_of_birth  patient_age patient_sex  \
# 0  V000001    PT00001 2022-03-15    1956-07-22           66        Male
# 1  V000002    PT00002 2022-04-22    1982-11-05           39      Female
# 2  V000003    PT00003 2022-05-10    1978-02-14           44        Male
# 3  V000004    PT00004 2023-01-18    2004-09-02           57      Female
# 4  V000005    PT00005 2023-07-30    1948-03-19           75        Male
#
#   icd_code  cpt_code
# 0      I10     12345
# 1    E11.9     23456
# 2  J45.909     34567
# 3    N39.0     45678
# 4  I25.110     56789
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   visit_id       200 non-null    str
#  1   patient_id     200 non-null    str
#  2   visit_date     200 non-null    datetime64[us]
#  3   date_of_birth  200 non-null    datetime64[us]
#  4   patient_age    200 non-null    int64
#  5   patient_sex    200 non-null    str
#  6   icd_code       200 non-null    str
#  7   cpt_code       200 non-null    int64
# dtypes: datetime64[us](2), int64(2), str(4)
# memory usage: 12.6 KB
# None

# %% [markdown]
# 2. Patient population overview

# %% [markdown]
# - 2.1 Validate age

# %%
df['age_from_DOB'] = ((df['visit_date'] - df['date_of_birth']).dt.days / 365.25).astype(int)
diff =df['patient_age']- df['age_from_DOB']

df['age_clean'] = np.where((df['age_from_DOB']).isna() | (diff.abs() > 2),
                           df['age_from_DOB'],
                           df['patient_age']
)

df.head(10)
# Out:
#   visit_id patient_id visit_date date_of_birth  patient_age patient_sex  \
# 0  V000001    PT00001 2022-03-15    1956-07-22           66        Male
# 1  V000002    PT00002 2022-04-22    1982-11-05           39      Female
# 2  V000003    PT00003 2022-05-10    1978-02-14           44        Male
# 3  V000004    PT00004 2023-01-18    2004-09-02           57      Female
# 4  V000005    PT00005 2023-07-30    1948-03-19           75        Male
# 5  V000006    PT00006 2023-11-12    1988-06-21           35      Female
# 6  V000007    PT00007 2024-02-08    1992-08-15           31      Female
# 7  V000008    PT00008 2024-03-23    1970-12-01           53        Male
# 8  V000009    PT00009 2022-09-14    1960-04-28           62      Female
# 9  V000010    PT00010 2022-12-07    1985-05-30           37        Male
#
#   icd_code  cpt_code  age_from_DOB  age_clean
# 0      I10     12345            65         66
# 1    E11.9     23456            39         39
# 2  J45.909     34567            44         44
# 3    N39.0     45678            18         18
# 4  I25.110     56789            75         75
# 5    F32.9     67890            35         35
# 6    M54.5     78901            31         31
# 7    K21.9     89012            53         53
# 8    E78.5     90123            62         62
# 9    F41.1     91234            37         37

# %% [markdown]
# - 2.2 Create age bands

# %%
bins = [0, 17, 39, 64, 200]
labels = ['0-17', '18-39', '40-64', '65+']

df['age_band'] = pd.cut(df['age_clean'], bins=bins, labels=labels, include_lowest=True)

df.head(10)
# Out:
#   visit_id patient_id visit_date date_of_birth  patient_age patient_sex  \
# 0  V000001    PT00001 2022-03-15    1956-07-22           66        Male
# 1  V000002    PT00002 2022-04-22    1982-11-05           39      Female
# 2  V000003    PT00003 2022-05-10    1978-02-14           44        Male
# 3  V000004    PT00004 2023-01-18    2004-09-02           57      Female
# 4  V000005    PT00005 2023-07-30    1948-03-19           75        Male
# 5  V000006    PT00006 2023-11-12    1988-06-21           35      Female
# 6  V000007    PT00007 2024-02-08    1992-08-15           31      Female
# 7  V000008    PT00008 2024-03-23    1970-12-01           53        Male
# 8  V000009    PT00009 2022-09-14    1960-04-28           62      Female
# 9  V000010    PT00010 2022-12-07    1985-05-30           37        Male
#
#   icd_code  cpt_code  age_from_DOB  age_clean age_band
# 0      I10     12345            65         66      65+
# 1    E11.9     23456            39         39    18-39
# 2  J45.909     34567            44         44    40-64
# 3    N39.0     45678            18         18    18-39
# 4  I25.110     56789            75         75      65+
# 5    F32.9     67890            35         35    18-39
# 6    M54.5     78901            31         31    18-39
# 7    K21.9     89012            53         53    40-64
# 8    E78.5     90123            62         62    40-64
# 9    F41.1     91234            37         37    18-39

# %% [markdown]
# - 2.3 Patient population by age

# %%
age_band_counts = df['age_band'].value_counts().reindex(labels)
age_band_counts
# Out:
# age_band
# 0-17       1
# 18-39     68
# 40-64    101
# 65+       30
# Name: count, dtype: int64

# %% [markdown]
# 3. Diagnosis analysis

# %% [markdown]
# - 3.1 Overall top diagnosis

# %%
top_icd = df['icd_code'].value_counts().head(10)
top_icd
# Out:
# icd_code
# I10        19
# J45.909    11
# N39.0      11
# E11.9      10
# M54.5      10
# E78.5      10
# F32.9       9
# K21.9       9
# I25.10      9
# G43.909     8
# Name: count, dtype: int64

# %%
top_5 = top_icd.head(5).index
top_icd_by_age_sex = (df[df['icd_code'].isin(top_5)].groupby(['icd_code', 'age_band', 'patient_sex'])
                    .size().reset_index(name='diagnosis_events').sort_values(by='diagnosis_events', ascending=False))

top_icd_by_age_sex
# Out:
#    icd_code age_band patient_sex  diagnosis_events
# 4       I10    40-64      Female                 6
# 1     E11.9    40-64      Female                 6
# 6       I10      65+      Female                 5
# 7       I10      65+        Male                 5
# 10  J45.909    40-64        Male                 5
# 17    N39.0    18-39      Female                 4
# 9   J45.909    40-64      Female                 4
# 19    N39.0    40-64      Female                 3
# 13    M54.5    18-39      Female                 3
# 15    M54.5    40-64      Female                 3
# 0     E11.9    18-39      Female                 2
# 2     E11.9    40-64        Male                 2
# 20    N39.0    40-64        Male                 2
# 5       I10    40-64        Male                 2
# 14    M54.5    18-39        Male                 2
# 18    N39.0    18-39        Male                 1
# 11  J45.909      65+      Female                 1
# 16    M54.5    40-64        Male                 1
# 12    M54.5     0-17        Male                 1
# 8   J45.909    18-39        Male                 1
# 3       I10    18-39        Male                 1
# 21    N39.0      65+      Female                 1

# %% [markdown]
# 4. Visit Utilization

# %% [markdown]
# - 4.1 Total diagnosis event per patient

# %%
diagnosis_events_per_patient = (df.groupby('patient_id')['icd_code'].count()
                                .reset_index(name='total_diagnosis_events').sort_values
                                (by='total_diagnosis_events', ascending=False))

diagnosis_events_per_patient
# Out:
#    patient_id  total_diagnosis_events
# 0     PT00001                       9
# 10    PT00011                       9
# 1     PT00002                       9
# 17    PT00018                       9
# 16    PT00017                       9
# 14    PT00015                       9
# 13    PT00014                       9
# 12    PT00013                       9
# 11    PT00012                       9
# 15    PT00016                       9
# 9     PT00010                       9
# 7     PT00008                       9
# 6     PT00007                       9
# 5     PT00006                       9
# 4     PT00005                       9
# 3     PT00004                       9
# 8     PT00009                       9
# 2     PT00003                       9
# 18    PT00019                       8
# 19    PT00020                       8
# 36    PT10015                       1
# 33    PT10012                       1
# 34    PT10013                       1
# 35    PT10014                       1
# 40    PT10019                       1
# 37    PT10016                       1
# 38    PT10017                       1
# 39    PT10018                       1
# 31    PT10010                       1
# 32    PT10011                       1
# 21    PT00022                       1
# 30    PT10009                       1
# 29    PT10008                       1
# 28    PT10007                       1
# 27    PT10006                       1
# 26    PT10005                       1
# 25    PT10004                       1
# 24    PT10003                       1
# 23    PT10002                       1
# 22    PT10001                       1
# 20    PT00021                       1
# 41    PT10020                       1

# %% [markdown]
# - 4.2 Average number of visits per patient

# %%
average_visits_per_patient = df.groupby('patient_id')['visit_id'].nunique().mean()
average_visits_per_patient
# Out:
# np.float64(1.4761904761904763)

# %% [markdown]
# - 4.3 High utilizers (patients with 4+ visits)

# %%
high_utilizers = diagnosis_events_per_patient[diagnosis_events_per_patient['total_diagnosis_events'] >= 4]
high_utilizers
# Out:
#    patient_id  total_diagnosis_events
# 0     PT00001                       9
# 10    PT00011                       9
# 1     PT00002                       9
# 17    PT00018                       9
# 16    PT00017                       9
# 14    PT00015                       9
# 13    PT00014                       9
# 12    PT00013                       9
# 11    PT00012                       9
# 15    PT00016                       9
# 9     PT00010                       9
# 7     PT00008                       9
# 6     PT00007                       9
# 5     PT00006                       9
# 4     PT00005                       9
# 3     PT00004                       9
# 8     PT00009                       9
# 2     PT00003                       9
# 18    PT00019                       8
# 19    PT00020                       8

# %% [markdown]
# 5. Procedure (CPT) Insights

# %% [markdown]
# - 5.1 Top performed procedures

# %%
top_cpt = df['cpt_code'].value_counts().head(10)
top_cpt
# Out:
# cpt_code
# 99213    7
# 99214    6
# 99204    6
# 12345    4
# 23456    4
# 34567    4
# 45678    4
# 56789    4
# 67890    4
# 78901    4
# Name: count, dtype: int64
